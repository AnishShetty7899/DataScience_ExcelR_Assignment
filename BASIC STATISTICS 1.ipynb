# %% [markdown]
# # BASIC STATISTICS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r"F:\Drive\ExcelR\Assignments\Basic stats - 1\Basic stats - 1\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
df_1= pd.DataFrame({'Mean':[df['Volume'].mean(),df['Avg Price'].mean(),df['Total Sales Value'].mean(),df['Discount Rate (%)'].mean(),df['Discount Amount'].mean(),df['Net Sales Value'].mean()],
                    'Median':[df['Volume'].median(),df['Avg Price'].median(),df['Total Sales Value'].median(),df['Discount Rate (%)'].median(),df['Discount Amount'].median(),df['Net Sales Value'].median()],
                    'Standred_Deviation':[df['Volume'].std(),df['Avg Price'].std(),df['Total Sales Value'].std(),df['Discount Rate (%)'].std(),df['Discount Amount'].std(),df['Net Sales Value'].std()],
                    'Mode':[df['Volume'].mode()[0],df['Avg Price'].mode()[0],df['Total Sales Value'].mode()[0],df['Discount Rate (%)'].mode()[0],df['Discount Amount'].mode()[0],df['Net Sales Value'].mode()[0]]}
                   ,index=['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value'],
                   columns=['Mean','Median','Standred_Deviation','Mode']
                  )

# %%
df_1
# Out:
#                            Mean       Median  Standred_Deviation          Mode
# Volume                 5.066667     4.000000            4.231602      3.000000
# Avg Price          10453.433333  1450.000000        18079.904840    400.000000
# Total Sales Value  33812.835556  5700.000000        50535.074173  24300.000000
# Discount Rate (%)     15.155242    16.577766            4.220602      5.007822
# Discount Amount     3346.499424   988.933733         4509.902963     69.177942
# Net Sales Value    30466.336131  4677.788059        46358.656624    326.974801

# %% [markdown]
# # Interpretation

# %% [markdown]
# Volume :
# mean: 5.07
# median: 4.0
# mode: 3
# standard deviation: 4.23
#
# For example, for Volume, the mean value is 5.07 that means the averge value of volume column is 5.07.
# Median is 4.0 i.e. the center value is 4.0.
# Mode is 3 i.e. the value 3 is appeared maximum times. i.e. frequency of 3 value is more.
# Standard deviation is 4.23 that means the values of Volumes are maximum deviated from mean 5.07 ie. 4.23 diffrence from mean 5.07.
# And similarly for all other columns too.

# %% [markdown]
# # Data Visualization

# %%
y=[,,,,,]

# %% [markdown]
# ### Histograms

# %%
figure, axis = plt.subplots(3,2)

axis[0,0].hist(df['Volume'])
axis[0,0].set_title('Volume')

axis[0,1].hist(df['Avg Price'])
axis[0,1].set_title('Avg Price')

axis[1,0].hist(df['Total Sales Value'])
axis[1,0].set_title('Total Sales Value')

axis[1,1].hist(df['Discount Rate (%)'])
axis[1,1].set_title('Discount Rate (%)')

axis[2,0].hist(df['Discount Amount'])
axis[2,0].set_title('Discount Amount')

axis[2,1].hist(df['Net Sales Value'])
axis[2,1].set_title('Net Sales Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# Volume is right screwed with outliers above 20,
# Avg price contains outliers at around 50000,
# Total sales and Net Sales value contains outliers around above 100000 value. same with discount amount above 20000,
# Discount rate % - non symentric binomial distributed with 2 modes. other all has only one mode.

# %% [markdown]
# ### Box Plot

# %%
figure, axis = plt.subplots(3,2)

axis[0,0].boxplot(df['Volume'])
axis[0,0].set_title('Volume')

axis[0,1].boxplot(df['Avg Price'])
axis[0,1].set_title('Avg Price')

axis[1,0].boxplot(df['Total Sales Value'])
axis[1,0].set_title('Total Sales Value')

axis[1,1].boxplot(df['Discount Rate (%)'])
axis[1,1].set_title('Discount Rate (%)')

axis[2,0].boxplot(df['Discount Amount'])
axis[2,0].set_title('Discount Amount')

axis[2,1].boxplot(df['Net Sales Value'])
axis[2,1].set_title('Net Sales Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### outliers and bound calcuation

# %%
#outliers calculation
print("For Volumn column:")
q1 = np.quantile(df['Volume'], 0.25)
q2 = np.quantile(df['Volume'], 0.50)
q3 = np.quantile(df['Volume'], 0.75)
iqr = q3-q1

# finding upper and lower bonds
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
print("Interquantile Range:[",q3,",",q1,"]")
print('The following are the outliers in the boxplot:')
for i in df['Volume']:
    if((i <= lower_bound) | (i >= upper_bound)):
        print(i, end=",")
# Out:
# For Volumn column:
# Interquantile Range:[ 6.0 , 3.0 ]
# The following are the outliers in the boxplot:
# 15,13,11,29,13,24,14,12,25,15,11,15,14,12,12,12,22,11,11,12,12,14,11,11,15,31,12,16,24,11,12,12,22,11,13,15,12,14,14,11,29,15,13,17,

# %%
#outliers calculation
print("For Avg Price column:")
q1 = np.quantile(df['Avg Price'], 0.25)
q2 = np.quantile(df['Avg Price'], 0.50)
q3 = np.quantile(df['Avg Price'], 0.75)
iqr = q3-q1

# finding upper and lower bonds
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
print("Interquantile Range:[",q3,",",q1,"]")
print('The following are the outliers in the boxplot:')
for i in df['Avg Price']:
    if((i <= lower_bound) | (i >= upper_bound)):
        print(i, end=",")
# Out:
# For Avg Price column:
# Interquantile Range:[ 10100.0 , 465.0 ]
# The following are the outliers in the boxplot:
# 49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,49100,54100,55100,60100,

# %%
#outliers calculation
print("For Total Sales Value column:")
q1 = np.quantile(df['Total Sales Value'], 0.25)
q2 = np.quantile(df['Total Sales Value'], 0.50)
q3 = np.quantile(df['Total Sales Value'], 0.75)
iqr = q3-q1

# finding upper and lower bonds
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
print("Interquantile Range:[",q3,",",q1,"]")
print('The following are the outliers in the boxplot:')
for i in df['Total Sales Value']:
    if((i <= lower_bound) | (i >= upper_bound)):
        print(i, end=",")
# Out:
# For Total Sales Value column:
# Interquantile Range:[ 53200.0 , 2700.0 ]
# The following are the outliers in the boxplot:
# 181500,147300,180300,133100,147300,165300,180300,196400,147300,147300,162300,162300,145200,147300,162300,165300,180300,169400,147300,181500,140700,147300,165300,145200,147300,165300,180300,165300,180300,140700,147300,133100,147300,157300,147300,165300,

# %%
#outliers calculation
print("For Discount Rate (%) column:")
q1 = np.quantile(df['Discount Rate (%)'], 0.25)
q2 = np.quantile(df['Discount Rate (%)'], 0.50)
q3 = np.quantile(df['Discount Rate (%)'], 0.75)
iqr = q3-q1

# finding upper and lower bonds
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
print("Interquantile Range:[",q3,",",q1,"]")
print('The following are the outliers in the boxplot:')
for i in df['Discount Rate (%)']:
    if((i <= lower_bound) | (i >= upper_bound)):
        print(i, end=",")
# Out:
# For Discount Rate (%) column:
# Interquantile Range:[ 18.114718477752703 , 13.965062543701741 ]
# The following are the outliers in the boxplot:
# 6.935385325,5.553719335858815,7.410104486,6.214888201701022,5.252112549273296,7.621790957934959,5.007822189204133,5.870670938165718,6.710453536396899,6.095201440402829,5.935084193732397,7.584590638090228,7.732667088605965,7.233846742335281,5.420506661087877,6.849975641919071,7.256695570137941,7.178725899241335,7.679385595700298,5.794802079132935,5.059801277154096,6.8582545692088726,7.208362951650773,7.341874344,6.473304705016388,6.439919959844064,7.421325599756022,6.268913808500697,6.819110662867928,6.170397894995827,5.072124185625713,6.106930704565366,6.508719077620175,6.066191918625036,5.084108426,6.326891692775114,6.415230294327099,5.055218412429214,5.4118021861669225,5.511042321019265,5.485156670073213,5.466379335661308,6.008199566158192,6.642595335085532,5.425910532590122,

# %%
#outliers calculation
print("For Discount Amount column:")
q1 = np.quantile(df['Discount Amount'], 0.25)
q2 = np.quantile(df['Discount Amount'], 0.50)
q3 = np.quantile(df['Discount Amount'], 0.75)
iqr = q3-q1

# finding upper and lower bonds
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
print("Interquantile Range:[",q3,",",q1,"]")
print('The following are the outliers in the boxplot:')
for i in df['Discount Amount']:
    if((i <= lower_bound) | (i >= upper_bound)):
        print(i, end=",")
# Out:
# For Discount Amount column:
# Interquantile Range:[ 5316.4954266866525 , 460.4593038855329 ]
# The following are the outliers in the boxplot:
# 21153.49881959317,13594.039718999667,17900.983733131387,17445.603828100593,13951.660194455462,16384.029009441005,16892.520950977458,15214.643323596902,12622.50365770546,17178.331859479713,12753.565957988514,13999.93849871122,17696.813620554134,25328.224204195907,13608.238319227805,25738.02219375868,21496.67536736378,16332.91992953586,14036.838652156111,12734.009012409486,13275.780741136909,16218.594720354302,13382.22733345896,15984.732280583024,

# %%
#outliers calculation
print("For Net Sales Value column:")
q1 = np.quantile(df['Net Sales Value'], 0.25)
q2 = np.quantile(df['Net Sales Value'], 0.50)
q3 = np.quantile(df['Net Sales Value'], 0.75)
iqr = q3-q1

# finding upper and lower bonds
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)
print("Interquantile Range:[",q3,",",q1,"]")
print('The following are the outliers in the boxplot:')
for i in df['Net Sales Value']:
    if((i <= lower_bound) | (i >= upper_bound)):
        print(i, end=",")
# Out:
# For Net Sales Value column:
# Interquantile Range:[ 47847.91285159138 , 2202.2086453212287 ]
# The following are the outliers in the boxplot:
# 160346.50118040683,133705.96028100033,162399.01626686862,139563.63821492044,151348.33980554453,163915.971,179507.47904902254,134677.49634229453,134731.95462498485,152667.35835357232,151182.48953316535,128021.66814052028,134546.43404201147,150648.92786553132,151300.0615012888,162603.18637944586,144071.7757958041,133691.7616807722,155761.9778062413,130557.83332702736,136485.41909127205,154937.48547454836,123703.3246326362,134934.94669153576,154541.08736469384,163967.08007046414,156895.96877157467,166263.16134784388,127965.99098759051,134024.2192588631,116881.4052796457,133917.77266654104,141315.26771941697,138449.92203904898,156330.96988962853,

# %% [markdown]
# ### Bar Chart Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df['Day']=df['Day'].astype('string')
df['SKU']=df['SKU'].astype('string')
df['City']=df['City'].astype('string')
df['BU']=df['BU'].astype('string')
df['Brand']=df['Brand'].astype('string')
df['Model']=df['Model'].astype('string')

# %%
df.dtypes
# Out:
# Date                         object
# Day                  string[python]
# SKU                  string[python]
# City                 string[python]
# Volume                        int64
# BU                   string[python]
# Brand                string[python]
# Model                string[python]
# Avg Price                     int64
# Total Sales Value             int64
# Discount Rate (%)           float64
# Discount Amount             float64
# Net Sales Value             float64
# dtype: object

# %%
df['Day'].value_counts().plot(kind="bar", title='Day', label="count")
plt.show()

# %%
df['City'].value_counts().plot(kind="bar", title='City', label="count")
plt.show()

# %%
df['SKU'].value_counts().plot(kind="bar", title='SKU', label="count")
plt.show()

# %%
df['BU'].value_counts().plot(kind="bar", title='BU', label="count")
plt.show()

# %%
df['Brand'].value_counts().plot(kind="bar", title='Brand', label="count")
plt.show()

# %%
df['Model'].value_counts().plot(kind="bar", title='Model', label="count")
plt.show()

# %%
df['Date'].value_counts().plot(kind="bar", title='Model', label="count")
plt.show()
