# %%
# IMPORT 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data set load
df= pd.read_csv(r"F:\Drive\ExcelR\Assignments\EDA1\EDA1\Cardiotocographic.csv")

# %% [markdown]
# # Tasks:

# %% [markdown]
# ## 1.	Data Cleaning and Preparation:

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
# Check data types and convert if necessary
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Handle missing values (if any)
df.fillna(df.median(), inplace=True)

# %%
# Verify if there are still missing values
print("Missing values after imputation:\n", df.isnull().sum())
# Out:
# Missing values after imputation:
#  LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#  Converting 'LB' column to integer 
df['LB'] = df['LB'].astype(int)

# %%
df.dtypes
# Out:
# LB            int32
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.head()
# Out:
#     LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 0  120  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0   2.4
# 1  132  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0  10.4
# 2  133  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0  13.4
# 3  134  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0  23.0
# 4  131  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0  19.9
#
#    Width  Tendency  NSP  Cluster
# 0   64.0  0.999926  2.0        1
# 1  130.0  0.000000  1.0        2
# 2  130.0  0.000000  1.0        2
# 3  117.0  1.000000  1.0        2
# 4  117.0  1.000000  1.0        2

# %%
# Check for duplicate rows and remove them
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2126, 14)

# %% [markdown]
# # 2. Statistical Summary

# %%
# Statistical summary for all columns
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.340204     0.003204     0.009894     0.004391     0.001895
# std      11.214379     0.004373     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000002     0.000173    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
# Additional statistics - interquartile range (IQR), skewness, kurtosis
iqr = df.quantile(0.75) - df.quantile(0.25)
print("Interquartile Range (IQR):\n", iqr)
# Out:
# Interquartile Range (IQR):
#  LB          14.000000
# AC           0.005612
# FM           0.002568
# UC           0.004678
# DL           0.003292
# DS           0.000000
# DP           0.000000
# ASTV        29.000000
# MSTV         1.000000
# ALTV        11.000000
# MLTV         6.200000
# Width       63.000000
# Tendency     1.000000
# NSP          0.000000
# dtype: float64

# %% [markdown]
# ## 3. Data Visualization:

# %%
# Set up the style for plots
sns.set(style="whitegrid")

# %%
# Histograms for numerical variables
df.hist(figsize=(14, 10), bins=20, color='teal', edgecolor='black')
plt.suptitle('Histograms of Numerical Variables')
plt.show()

# %%
# Boxplots to detect outliers
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, palette="coolwarm")
plt.title('Boxplots of Numerical Variables')
plt.xticks(rotation=90)
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Scatter plots between pairs of variables
sns.pairplot(df, diag_kind="kde", plot_kws={"s": 5})
plt.suptitle('Pairplot of Numerical Variables', y=1.02)
plt.show()

# %%
# Pairplot with hue based on the categorical variable
plt.figure(figsize=(12, 10))
sns.pairplot(data, hue='NSP')
plt.show()

# %% [markdown]
# # 4. Pattern Recognition and Insights
#
# This section identifies correlations between variables in the dataset and discusses their potential implications.

# %%
# Display the full correlation matrix
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063391  0.019339 -0.166782 -0.126450 -0.005043
# AC       -0.063391  1.000000  0.009743  0.071313 -0.093581 -0.033097
# FM        0.019339  0.009743  1.000000 -0.053386  0.009641  0.029914
# UC       -0.166782  0.071313 -0.053386  1.000000  0.189737 -0.006958
# DL       -0.126450 -0.093581  0.009641  0.189737  1.000000  0.058413
# DS       -0.005043 -0.033097  0.029914 -0.006958  0.058413  1.000000
# DP       -0.047614 -0.083350  0.121434  0.070144  0.144631  0.004317
# ASTV      0.241729 -0.231086 -0.032838 -0.182379 -0.069907  0.008415
# MSTV     -0.169125  0.133215  0.017061  0.189685  0.410216  0.016028
# ALTV      0.210798 -0.269967 -0.012005 -0.227881 -0.187275 -0.004344
# MLTV     -0.003199 -0.104635 -0.006041 -0.048854 -0.165035  0.034384
# Width    -0.118308  0.234534  0.097204  0.106474  0.408340  0.040844
# Tendency  0.237057  0.031630 -0.017888 -0.067314 -0.024180 -0.015304
# ...

# %% [markdown]
# ### Insights from Correlation Analysis
#
# 1. **MSTV and Width (0.43)**: Moderate positive correlation suggests that as Mean Short-Term Variability (MSTV) increases, the Width of the signal tends to increase.
#
# 2. **ASTV and NSP (0.42)**: Moderate positive correlation between Abnormal Short-Term Variability (ASTV) and fetal state classification (NSP) indicates a relationship that could help identify at-risk fetuses.
#
# 3. **ALTV and NSP (0.37)**: Suggests that Accelerations in Long-Term Variability (ALTV) have a moderate positive relationship with fetal state classification.
#
# 4. **ASTV and MSTV (-0.29)**: Negative correlation suggests that as abnormal short-term variability increases, the mean short-term variability decreases.
#
# 5. **ALTV and Width (-0.35)**: Negative correlation implies that greater long-term accelerations are associated with narrower heart rate patterns.
#
# 6. **AC and NSP (-0.31)**: Negative correlation indicates that more frequent accelerations are associated with less favorable fetal states.

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# - **Key Insights:**
#   - The dataset revealed strong correlations between `ASTV` and `MSTV`, suggesting that they are closely related in predicting fetal health.
#   - The boxplots indicated potential outliers in `Width` and `MLTV`, which could affect the model's accuracy if not addressed.
#   - The skewness in the `AC` variable suggests that the data is highly right-skewed, indicating that most observations have low AC values, with a few significantly higher.
#
# - **Recommendations:**
#   - Further investigate the outliers in `Width` and `MLTV` to determine if they are data entry errors or require special treatment.
#   - Consider using the strong correlation between `ASTV` and `MSTV` to reduce dimensionality or improve prediction accuracy in models.
#   - Address the skewness in the `AC` variable by applying a logarithmic transformation or similar technique to normalize the distribution before further analysis.
